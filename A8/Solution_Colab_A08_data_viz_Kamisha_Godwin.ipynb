# %% [markdown]
# # Data Visualization exercise

# %%
# importing the package(s) we want to use
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
### The input file is tab-delimited
tsv_Filepath = "https://raw.githubusercontent.com/csbfx/advpy122-data/master/euk.tsv"
# we can specify the delimiter by using the sep keyword argument
euk = pd.read_csv(tsv_Filepath, sep='\t')

# %%
### Using .head() and .tail() to see data content
euk.head()
# Out:
#                       Species   Kingdom           Class  Size (Mb)      GC%  \
# 0  Emiliania huxleyi CCMP1516  Protists  Other Protists    167.676     64.5
# 1        Arabidopsis thaliana    Plants     Land Plants    119.669  36.0529
# 2                 Glycine max    Plants     Land Plants    979.046  35.1153
# 3         Medicago truncatula    Plants     Land Plants    412.924   34.047
# 4        Solanum lycopersicum    Plants     Land Plants    828.349  35.6991
#
#   Number of genes Number of proteins  Publication year Assembly status
# 0           38549              38554              2013        Scaffold
# 1           38311              48265              2001      Chromosome
# 2           59847              71219              2010      Chromosome
# 3           37603              41939              2011      Chromosome
# 4           31200              37660              2010      Chromosome

# %%
euk
# Out:
#                          Species   Kingdom           Class   Size (Mb)  \
# 0     Emiliania huxleyi CCMP1516  Protists  Other Protists  167.676000
# 1           Arabidopsis thaliana    Plants     Land Plants  119.669000
# 2                    Glycine max    Plants     Land Plants  979.046000
# 3            Medicago truncatula    Plants     Land Plants  412.924000
# 4           Solanum lycopersicum    Plants     Land Plants  828.349000
# ...                          ...       ...             ...         ...
# 8297    Saccharomyces cerevisiae     Fungi     Ascomycetes    3.993920
# 8298    Saccharomyces cerevisiae     Fungi     Ascomycetes    0.586761
# 8299    Saccharomyces cerevisiae     Fungi     Ascomycetes   12.020400
# 8300    Saccharomyces cerevisiae     Fungi     Ascomycetes   11.960900
# 8301    Saccharomyces cerevisiae     Fungi     Ascomycetes   11.820700
#
#           GC% Number of genes Number of proteins  Publication year  \
# 0        64.5           38549              38554              2013
# 1     36.0529           38311              48265              2001
# 2     35.1153           59847              71219              2010
# 3      34.047           37603              41939              2011
# 4     35.6991           31200              37660              2010
# ...       ...             ...                ...               ...
# 8297     38.2               -                  -              2017
# 8298  38.5921             155                298              1992
# 8299  38.2971               -                  -              2018
# 8300  38.2413               -                  -              2018
# 8301  38.2536               -                  -              2018
#
#      Assembly status
# 0           Scaffold
# 1         Chromosome
# 2         Chromosome
# 3         Chromosome
# 4         Chromosome
# ...              ...
# 8297        Scaffold
# 8298      Chromosome
# 8299      Chromosome
# 8300      Chromosome
# 8301      Chromosome
#
# [8302 rows x 9 columns]

# %%
### .info() to provide information on the data
euk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8302 entries, 0 to 8301
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Species             8302 non-null   object
#  1   Kingdom             8302 non-null   object
#  2   Class               8302 non-null   object
#  3   Size (Mb)           8302 non-null   float64
#  4   GC%                 8302 non-null   object
#  5   Number of genes     8302 non-null   object
#  6   Number of proteins  8302 non-null   object
#  7   Publication year    8302 non-null   int64
#  8   Assembly status     8302 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage:
# 3496        Chelonoidis abingdonii  Animals  Reptiles    2300.75  45.4000
# 3747                 Cuora mccordi  Animals  Reptiles    2390.37  44.6000
# 3810        Hydrophis cyanocinctus  Animals  Reptiles    1389.86  37.6000
# 3811          Hydrophis hardwickii  Animals  Reptiles    1296.39  37.2000
# 4556            Crocodylus porosus  Animals  Reptiles    2120.57  44.3000
# 4561    Alligator mississippiensis  Animals  Reptiles    2161.71  44.3000
# 5274    Alligator mississippiensis  Animals  Reptiles    2156.98  44.3000
#
#       Number of genes  Number of proteins  Publication year Assembly status
# 282           22092.0             34827.0              2007      Chromosome
# 543               NaN                 NaN              2018        Scaffold
# 565           21445.0             38203.0              2015        Scaffold
# 589               NaN                 NaN              2018        Scaffold
# 612               NaN                 NaN              2019      Chromosome
# 650               NaN                 NaN              2019        Scaffold
# 730               NaN                 NaN              2013        Scaffold
# 944           25289.0             46651.0              2012      Chromosome
# 1122          22336.0             28672.0              2013        Scaffold
# 1136          25012.0             42388.0              2012        Scaffold
# 1150          19551.0             28676.0              2016        Scaffold
# 1218          22413.0             31232.0              2018        Scaffold
# 1224              NaN                 NaN              2014        Scaffold
# 1248          24516.0             38587.0              2012        Scaffold
# 1294              NaN                 NaN              2013        Scaffold
# 1372              NaN                 NaN              2016        Scaffold
# 1376          20101.0             25180.0              2015        Scaffold
# 1513          21877.0             32724.0              2013        Scaffold
# 1526          21073.0             22660.0              2016        Scaffold
# 1576          24320.0             43105.0              2013        Scaffold
# 2135              NaN                 NaN              2015        Scaffold
# 2142          21197.0             24192.0              2015        Scaffold
# 2175              NaN                 NaN              2018        Scaffold
# 2186              NaN                 NaN              2018          Contig
# 2425              NaN                 NaN              2018        Scaffold
# 2519             13.0                13.0              2016          Contig
# 2808              NaN                 NaN              2014        Scaffold
# 2830              NaN                 NaN              2018        Scaffold
# 3021              NaN                 NaN              2018        Scaffold
# 3054          24657.0             36743.0              2018        Scaffold
# 3239              NaN                 NaN              2018          Contig
# 3463              NaN                 NaN              2018      Chromosome
# 3487          22151.0             31677.0              2018        Scaffold
# 3495              NaN                 NaN              2018        Scaffold
# 3496              NaN                 NaN              2018        Scaffold
# 3747              NaN                 NaN              2018        Scaffold
# 3810              NaN                 NaN              2019        Scaffold
# 3811              NaN                 NaN              2019        Scaffold
# 4556              NaN                 NaN              2014        Scaffold
# 4561              NaN                 NaN              2016        Scaffold
# 5274              NaN                 NaN              2016        Scaffold

# %%
## Pick out data for just Reptiles with genome size < 4000
reptiles_4000 = euk[(euk["Class"] == "Reptiles") & (euk["Size (Mb)"] < 4000)]
reptiles_4000
# Out:
#                            Species  Kingdom     Class  Size (Mb)      GC%  \
# 282            Anolis carolinensis  Animals  Reptiles    1799.14  40.8238
# 565               Pogona vitticeps  Animals  Reptiles    1716.68  42.1000
# 589      Platysternon megacephalum  Animals  Reptiles    2319.09  43.9000
# 730               NaN                 NaN              2013        Scaffold
# 944           25289.0             46651.0              2012      Chromosome
# 1122          22336.0             28672.0              2013        Scaffold
# 1136          25012.0             42388.0              2012        Scaffold
# 1150          19551.0             28676.0              2016        Scaffold
# 1218          22413.0             31232.0              2018        Scaffold
# 1224              NaN                 NaN              2014        Scaffold
# 1248          24516.0             38587.0              2012        Scaffold
# 1294              NaN                 NaN              2013        Scaffold
# 1372              NaN                 NaN              2016        Scaffold
# 1376          20101.0             25180.0              2015        Scaffold
# 1513          21877.0             32724.0              2013        Scaffold
# 1526          21073.0             22660.0              2016        Scaffold
# 1576          24320.0             43105.0              2013        Scaffold
# 2135              NaN                 NaN              2015        Scaffold
# 2142          21197.0             24192.0              2015        Scaffold
# 2175              NaN                 NaN              2018        Scaffold
# 2186              NaN                 NaN              2018          Contig
# 2425              NaN                 NaN              2018        Scaffold
# 2519             13.0                13.0              2016          Contig
# 2808              NaN                 NaN              2014        Scaffold
# 2830              NaN                 NaN              2018        Scaffold
# 3021              NaN                 NaN              2018        Scaffold
# 3054          24657.0             36743.0              2018        Scaffold
# 3239              NaN                 NaN              2018          Contig
# 3463              NaN                 NaN              2018      Chromosome
# 3487          22151.0             31677.0              2018        Scaffold
# 3495              NaN                 NaN              2018        Scaffold
# 3496              NaN                 NaN              2018        Scaffold
# 3747              NaN                 NaN              2018        Scaffold
# 3810              NaN                 NaN              2019        Scaffold
# 3811              NaN                 NaN              2019        Scaffold
# 4556              NaN                 NaN              2014        Scaffold
# 4561              NaN                 NaN              2016        Scaffold
# 5274              NaN                 NaN              2016        Scaffold

# %% [markdown]
# ### Use `relplot` to look at relationships
# We will use the `relplot` function, and the names of the columns that we want on the `X` and `Y` axes to look at the relationship between genome size and number of genes in Reptiles

# %%
### Relationship plot between genome size and number of genes in Retiles
import seaborn as sns
import matplotlib.pyplot as plt
sns.relplot(data=euk,x="Size (Mb)",y="Number of genes")
plt.title("Relationship between Genome Size and Number of genes")
# Out:
# Text(0.5, 1.0, 'Relationship between Genome Size and Number of genes')

# %% [markdown]
# ### Can you create a new column to look at gene density?
# gene density = Number of genes / Size (Mb)

# %%
### Your Code
# gene density = Number of genes / Size (Mb)
# create the new column
euk["Gene Density"] = euk["Number of genes"] / euk["Size (Mb)"]
euk
# Out:
#                          Species   Kingdom           Class   Size (Mb)  \
# 0     Emiliania huxleyi CCMP1516  Protists  Other Protists  167.676000
# 1           Arabidopsis thaliana    Plants     Land Plants  119.669000
# 2                    Glycine max    Plants     Land Plants  979.046000
# 3            Medicago truncatula    Plants     Land Plants  412.924000
# 4           Solanum lycopersicum    Plants     Land Plants  828.349000
# ...                          ...       ...             ...         ...
# 8297    Saccharomyces cerevisiae     Fungi     Ascomycetes    3.993920
# 8298    Saccharomyces cerevisiae     Fungi     Ascomycetes    0.586761
# 8299    Saccharomyces cerevisiae     Fungi     Ascomycetes   12.020400
# 8300    Saccharomyces cerevisiae     Fungi     Ascomycetes   11.960900
# 8301    Saccharomyces cerevisiae     Fungi     Ascomycetes   11.820700
#
#           GC%  Number of genes  Number of proteins  Publication year  \
# 0     64.5000          38549.0             38554.0              2013
# 1     36.0529          38311.0             48265.0              2001
# 2     35.1153          59847.0             71219.0              2010
# 3     34.0470          37603.0             41939.0              2011
# 4     35.6991          31200.0             37660.0              2010
# ...       ...              ...                 ...               ...
# 8297  38.2000              NaN                 NaN              2017
# 8298  38.5921            155.0               298.0              1992
# 8299  38.2971              NaN                 NaN              2018
# 8300  38.2413              NaN                 NaN              2018
# 8301  38.2536              NaN                 NaN              2018
#
#      Assembly status  Gene Density
# 0           Scaffold    229.901715
# 1         Chromosome    320.141390
# 2         Chromosome     61.127873
# 3         Chromosome     91.065184
# 4         Chromosome     37.665284
# ...              ...           ...
# 8297        Scaffold           NaN
# 8298      Chromosome    264.162069
# 8299      Chromosome           NaN
# 8300      Chromosome           NaN
# 8301      Chromosome           NaN
#
# [8302 rows x 10 columns]

# %%
### Create the plot that represents the relation between Size (Mb) and density
# Is it what you expected?
import seaborn as sns
sns.relplot(data=euk,x="Size (Mb)",y="Gene Density")
plt.title("Relationshi[p between Size and Gene Density",pad=10)
# Out:
# Text(0.5, 1.0, 'Relationshi[p between Size and Gene Density')

# %% [markdown]
# ANSWER:-
# Expected Relationship: I anticipated an inverse relationship, where larger genome sizes would correspond to lower gene density due to the presence of more non-coding regions.
#
# Actual Observation: The plot confirmed this expectation, showing that as genome size increases, gene density tends to decrease.

# %%
import seaborn as sns
sns.relplot(data=euk,x="Size (Mb)",y="Gene Density")
plt.title("Relationshi[p between Size and Gene Density",pad=10)

# %% [markdown]
# ## Seaborn
# These are other `kind` plots that we did not try in lectures. Look up seaborn documentation and try to create these new plots.
#
# 1.   Create a violin plot for genome size distribution against Class Land Plants.
# 2.   Create a scatter plot showing the relationship between Kingdom and Publication year
# 3. Create a bar plot for GC% for each Kingdom

# %%
### Your code - Create a violin plot for genome size distribution against Class Land Plants.
sns.violinplot(data=euk[euk["Class"] == "Land Plants"], x="Class", y="Size (Mb)")
plt.title("Genome Size Distribution for Land Plants",pad=10)
plt.show()

# %%
### Your code - Create a scatter plot showing the relationship between Kingdom and Publication year
sns.scatterplot(data=euk, x="Publication year", y="Kingdom", alpha=0.5)
plt.title("Relationship Between Kingdom and Publication Year")
plt.show()

# %%
### Your code - Create a bar plot for GC% for each Kingdom
sns.barplot(data=euk, x="Kingdom", y="GC%")
plt.title("GC% for Each Kingdom")
plt.xticks(rotation=45)  # Rotates labels for better readability
plt.show()

# %%
sns.barplot(
    data=euk.dropna(),
    x="Kingdom",
    y="GC%",
    hue="Class"
)
plt.xticks(rotation=45)  # Rotate labels for readability
plt.title("GC% for Each Kingdom \n Grouped by Class");
plt.show()
